# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('life_expectancy.csv')

# %%
data.head()
# Out:
#         Entity Code  Year  LifeExpectancy
# 0  Afghanistan  AFG  1950         27.7275
# 1  Afghanistan  AFG  1951         27.9634
# 2  Afghanistan  AFG  1952         28.4456
# 3  Afghanistan  AFG  1953         28.9304
# 4  Afghanistan  AFG  1954         29.2258

# %%
kazakhstan_data = data[data['Entity'] == 'Kazakhstan']

# %%
kazakhstan_data = kazakhstan_data[:-7]

# %%
df = pd.DataFrame(kazakhstan_data)

# %%
kazakhstan_data
# Out:
#           Entity Code  Year  LifeExpectancy
# 9264  Kazakhstan  KAZ  1950         56.0542
# 9265  Kazakhstan  KAZ  1951         56.1866
# 9266  Kazakhstan  KAZ  1952         56.3799
# 9267  Kazakhstan  KAZ  1953         56.5799
# 9268  Kazakhstan  KAZ  1954         56.9012
# ...          ...  ...   ...             ...
# 9331  Kazakhstan  KAZ  2017         71.3958
# 9332  Kazakhstan  KAZ  2018         71.4717
# 9333  Kazakhstan  KAZ  2019         71.5675
# 9334  Kazakhstan  KAZ  2020         70.0304
# 9335  Kazakhstan  KAZ  2021         69.3622
#
# [72 rows x 4 columns]

# %%
df.to_excel('kazakhstan_data.xlsx', index=False)

# %%
plt.plot(kazakhstan_data['Year'], kazakhstan_data['LifeExpectancy'])
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy in Kazakhstan from 1950 to 2021')
plt.grid(True)
plt.savefig('life_expactancy_in_kazakhstan.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data_ages = pd.read_csv('life_expectancy_different_ages.csv')

# %%
data_ages
# Out:
#             Entity Code  Year  LifeExpectancy0  LifeExpectancy10  \
# 0      Afghanistan  AFG  1950          27.7275           49.1459
# 1      Afghanistan  AFG  1951          27.9634           49.2941
# 2      Afghanistan  AFG  1952          28.4456           49.5822
# 3      Afghanistan  AFG  1953          28.9304           49.8634
# 4      Afghanistan  AFG  1954          29.2258           49.9306
# ...            ...  ...   ...              ...               ...
# 20750     Zimbabwe  ZWE  2017          60.7095           64.6277
# 20751     Zimbabwe  ZWE  2018          61.4141           65.1821
# 20752     Zimbabwe  ZWE  2019          61.2925           65.0582
# 20753     Zimbabwe  ZWE  2020          61.1242           64.8006
# 20754     Zimbabwe  ZWE  2021          59.2531           62.8058
#
#        LifeExpectancy25  LifeExpectancy45  LifeExpectancy65  LifeExpectancy80
# 0             54.442200         63.422500           73.4901           83.7259
# ...

# %%
kazakhstan_ages = data_ages[data_ages['Entity'] == 'Kazakhstan']

# %%
kazakhstan_ages = kazakhstan_ages[:-7]

# %%
data_ages[['LifeExpectancy0', 'LifeExpectancy10', 'LifeExpectancy25', 'LifeExpectancy45', 'LifeExpectancy65', 'LifeExpectancy80']] = data_ages[['LifeExpectancy0', 'LifeExpectancy10', 'LifeExpectancy25', 'LifeExpectancy45', 'LifeExpectancy65', 'LifeExpectancy80']].apply(lambda x: x.astype(float).round(2))

# %%
kazakhstan_ages
# Out:
#           Entity Code  Year  LifeExpectancy0  LifeExpectancy10  \
# 9264  Kazakhstan  KAZ  1950            56.05             65.02
# 9265  Kazakhstan  KAZ  1951            56.19             65.08
# 9266  Kazakhstan  KAZ  1952            56.38             65.11
# 9267  Kazakhstan  KAZ  1953            56.58             65.18
# 9268  Kazakhstan  KAZ  1954            56.90             65.36
# ...          ...  ...   ...              ...               ...
# 9331  Kazakhstan  KAZ  2017            71.40             72.22
# 9332  Kazakhstan  KAZ  2018            71.47             72.28
# 9333  Kazakhstan  KAZ  2019            71.57             72.36
# 9334  Kazakhstan  KAZ  2020            70.03             70.79
# 9335  Kazakhstan  KAZ  2021            69.36             70.10
#
#       LifeExpectancy25  LifeExpectancy45  LifeExpectancy65  LifeExpectancy80
# 9264             66.90             70.41             76.87             85.15
# ...

# %%
kazakhstan_ages.plot(kind='line')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy Trends in Kazakhstan')
plt.savefig('life_expectancy_different_ages_in_kazakhstan')
plt.show()

# %%
kazakhstan_ages
# Out:
#           Entity Code  LifeExpectancy0  LifeExpectancy10  LifeExpectancy25  \
# Year
# 1950  Kazakhstan  KAZ            56.05             65.02             66.90
# 1951  Kazakhstan  KAZ            56.19             65.08             66.96
# 1952  Kazakhstan  KAZ            56.38             65.11             67.00
# 1953  Kazakhstan  KAZ            56.58             65.18             67.06
# 1954  Kazakhstan  KAZ            56.90             65.36             67.22
# ...          ...  ...              ...               ...               ...
# 2017  Kazakhstan  KAZ            71.40             72.22             72.73
# 2018  Kazakhstan  KAZ            71.47             72.28             72.77
# 2019  Kazakhstan  KAZ            71.57             72.36             72.83
# 2020  Kazakhstan  KAZ            70.03             70.79             71.21
# 2021  Kazakhstan  KAZ            69.36             70.10             70.52
#
#       LifeExpectancy45  LifeExpectancy65  LifeExpectancy80
# ...
